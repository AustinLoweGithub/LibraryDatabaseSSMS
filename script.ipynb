-- %% [markdown]
-- # [dbo].[spAddUser]

-- %%
USE [Library]
GO

-- %%
/****** Object:  StoredProcedure [dbo].[spAddUser]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author: <Author,,Name>
-- Create date: <Create Date,,>
-- Description: <Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spAddUser] 
(@ParamLastName nvarchar, @ParamFirstName nvarchar, @ParamUserName nvarchar, @ParamPassword nvarchar, @ParamRoleID int)
AS
BEGIN
-- SET NOCOUNT ON added to prevent extra result sets from
-- interfering with SELECT statements.
SET NOCOUNT ON;


    -- Insert statements for procedure here
INSERT INTO [User](LastName, FirstName, UserName, [Password], RoleID_FK)
VALUES (@ParamLastName,@ParamFirstName, @ParamUserName, @ParamPassword, @ParamRoleID)
END
GO

-- %% [markdown]
-- # [dbo].[spCreateAuthor]

-- %%
/****** Object:  StoredProcedure [dbo].[spCreateAuthor]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spCreateAuthor]  
	-- Add the parameters for the stored procedure here
	
	(@ParamFirstName nvarchar, @ParamLastName nvarchar, @ParamBio nvarchar,@ParamDateOfBirth datetime, @ParamBirthLocation nvarchar)


AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	--SELECT <@Param1, sysname, @p1>, <@Param2, sysname, @p2>

	INSERT INTO Author (FirstName, LastName, Bio, DateOfBirth, BirthLocation) VALUES (@ParamFirstName, @ParamLastName, @ParamBio, @ParamDateOfBirth, @ParamBirthLocation);

END
GO

-- %% [markdown]
-- # [dbo].[spCreatePublisher]

-- %%
/****** Object:  StoredProcedure [dbo].[spCreatePublisher]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author: <Author,,Name>
-- Create date: <Create Date,,>
-- Description: <Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spCreatePublisher] 
-- Add the parameters for the stored procedure here

@ParamPublisherName nvarchar,
@ParamPublisherCity nvarchar,
@ParamPublisherState nvarchar,
@ParamPublisherAddress nvarchar,
@ParamPublisherZip int
AS
BEGIN
-- SET NOCOUNT ON added to prevent extra result sets from
-- interfering with SELECT statements.
SET NOCOUNT ON;


    -- Insert statements for procedure here
Insert into Publisher ( [Name],City,[State],[Address],Zip)
Values (@ParamPublisherName,@ParamPublisherCity,@ParamPublisherState,@ParamPublisherAddress, @ParamPublisherZip);


END
GO

-- %% [markdown]
-- # [dbo].[spCreateRole]

-- %%
/****** Object:  StoredProcedure [dbo].[spCreateRole]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spCreateRole]
	-- Add the parameters for the stored procedure here
	@ParamRoleName nvarchar
	--@ParamRoleID int
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
   INSERT INTO [Role] (RoleName) VALUES (@ParamRoleName);


   --UPDATE Role SET RoleName = @ParamRoleName WHERE RoleID = @ParamRoleID;

END
GO

-- %% [markdown]
-- # [dbo].[spDeleteAuthor]

-- %%
/****** Object:  StoredProcedure [dbo].[spDeleteAuthor]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spDeleteAuthor]
	-- Add the parameters for the stored procedure here
	@ParamAuthorID int


AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	DELETE FROM Author WHERE AuthorID = @ParamAuthorID;
END
GO

-- %% [markdown]
-- # [dbo].[spDeletePublisher]

-- %%
/****** Object:  StoredProcedure [dbo].[spDeletePublisher]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author: <Author,,Name>
-- Create date: <Create Date,,>
-- Description: <Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spDeletePublisher]
-- Add the parameters for the stored procedure here
@ParamPublisherID int

AS
BEGIN
-- SET NOCOUNT ON added to prevent extra result sets from
-- interfering with SELECT statements.
SET NOCOUNT ON;


    -- Insert statements for procedure here
Delete From Publisher where PublisherID = @ParamPublisherID;
END
GO

-- %% [markdown]
-- # [dbo].[spDeleteRole]

-- %%
/****** Object:  StoredProcedure [dbo].[spDeleteRole]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spDeleteRole]
	-- Add the parameters for the stored procedure here
	@ParamRoleID int
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	DELETE FROM Role WHERE RoleID = @ParamRoleID;

END
GO

-- %% [markdown]
-- # [dbo].[spDeleteUser]

-- %%
/****** Object:  StoredProcedure [dbo].[spDeleteUser]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author: <Author,,Name>
-- Create date: <Create Date,,>
-- Description: <Description,,>
-- =============================================
Create PROCEDURE [dbo].[spDeleteUser] 
(@ParamUserID int)
AS
BEGIN
-- SET NOCOUNT ON added to prevent extra result sets from
-- interfering with SELECT statements.
SET NOCOUNT ON;




    -- Insert statements for procedure here
DELETE FROM [User] WHERE UserID = @ParamUserID
END
GO

-- %% [markdown]
-- # [dbo].[spGetAuthor]

-- %%
/****** Object:  StoredProcedure [dbo].[spGetAuthor]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Austin>
-- Create date: <4-14-21>
-- Description:	<Read/Get Author>
-- =============================================
CREATE PROCEDURE [dbo].[spGetAuthor]
	-- Add the parameters for the stored procedure here
	
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	Select * FROM Author
END
GO

-- %% [markdown]
-- # [dbo].[spGetPublisher]

-- %%
/****** Object:  StoredProcedure [dbo].[spGetPublisher]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author: <Author,,Name>
-- Create date: <Create Date,,>
-- Description: <Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spGetPublisher] 
@ParamPublisherID int
AS
BEGIN
-- SET NOCOUNT ON added to prevent extra result sets from
-- interfering with SELECT statements.
SET NOCOUNT ON;


    -- Insert statements for procedure here
SELECT * From Publisher Where PublisherID = @ParamPublisherID
END
GO

-- %% [markdown]
-- # [dbo].[spGetRole]

-- %%
/****** Object:  StoredProcedure [dbo].[spGetRole]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spGetRole]
	-- Add the parameters for the stored procedure here
	--<@Param1, sysname, @p1> <Datatype_For_Param1, , int> = <Default_Value_For_Param1, , 0>, 
	--<@Param2, sysname, @p2> <Datatype_For_Param2, , int> = <Default_Value_For_Param2, , 0>
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT RoleID, RoleName FROM Role;
END
GO

-- %% [markdown]
-- # [dbo].[spGetUser]

-- %%
/****** Object:  StoredProcedure [dbo].[spGetUser]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author: <Author,,Name>
-- Create date: <Create Date,,>
-- Description: <Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spGetUser] 

AS
BEGIN
-- SET NOCOUNT ON added to prevent extra result sets from
-- interfering with SELECT statements.
SET NOCOUNT ON;


    -- Insert statements for procedure here
SELECT * FROM [User]
END
GO

-- %% [markdown]
-- # [dbo].[spUpdateAuthor]

-- %%
/****** Object:  StoredProcedure [dbo].[spUpdateAuthor]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Austin>
-- Create date: <4-14-21>
-- Description:	<Update Author>
-- =============================================
CREATE PROCEDURE [dbo].[spUpdateAuthor]
	-- Add the parameters for the stored procedure here
	(@ParamAuthorID int, @ParamFirstName nvarchar, @ParamLastName nvarchar, @ParamBio nvarchar,@ParamDateOfBirth datetime, @ParamBirthLocation nvarchar)
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	UPDATE [Author] SET FirstName = @ParamFirstName, LastName = @ParamLastName, Bio = @ParamBio, DateOfBirth = @ParamDateOfBirth, BirthLocation = @ParamBirthLocation
	WHERE AuthorID = @ParamAuthorID
END
GO

-- %% [markdown]
-- # [dbo].[spUpdatePublisher]

-- %%
/****** Object:  StoredProcedure [dbo].[spUpdatePublisher]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author: <Author,,Name>
-- Create date: <Create Date,,>
-- Description: <Description,,>
-- =============================================


CREATE PROCEDURE [dbo].[spUpdatePublisher] 
-- Add the parameters for the stored procedure here
@ParamPublisherID int,
@ParamPublisherName nvarchar,
@ParamPublisherCity nvarchar,
@ParamPublisherState nvarchar,
@ParamPublisherAddress nvarchar,
@ParamPublisherZip int
AS
BEGIN
-- SET NOCOUNT ON added to prevent extra result sets from
-- interfering with SELECT statements.
SET NOCOUNT ON;


    -- Insert statements for procedure here
Update Publisher Set [Name] = @ParamPublisherName, City = @ParamPublisherCity ,
[State] = @ParamPublisherState, [Address] = @ParamPublisherAddress, [Zip] = @ParamPublisherZip
Where PublisherID = @ParamPublisherID


END
GO

-- %% [markdown]
-- # [dbo].[spUpdateRole]

-- %%
/****** Object:  StoredProcedure [dbo].[spUpdateRole]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[spUpdateRole]
	-- Add the parameters for the stored procedure here
	@ParamRoleName nvarchar,
	@ParamRoleID int
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
   UPDATE Role SET RoleName = @ParamRoleName WHERE RoleID = @ParamRoleID;


   --UPDATE Role SET RoleName = @ParamRoleName WHERE RoleID = @ParamRoleID;

END
GO

-- %% [markdown]
-- # [dbo].[spUpdateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[spUpdateUser]    Script Date: 4/15/2021 11:27:50 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author: <Author,,Name>
-- Create date: <Create Date,,>
-- Description: <Description,,>
-- =============================================
Create PROCEDURE [dbo].[spUpdateUser] 
(@ParamUserID int, @ParamLastName nvarchar, @ParamFirstName nvarchar, @ParamUserName nvarchar, @ParamPassword nvarchar, @ParamRoleID int)
AS
BEGIN
-- SET NOCOUNT ON added to prevent extra result sets from
-- interfering with SELECT statements.
SET NOCOUNT ON;


    -- Insert statements for procedure here
Update [User] SET LastName = @ParamLastName, FirstName = @ParamFirstName, UserName = @ParamFirstName, [Password] = @ParamPassword, RoleID_FK = @ParamRoleID
WHERE UserID = @ParamUserID
END
GO
